# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RayyanA24/flyrank-ml-internship/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*
# ## Ranked Actions and Reason Codes
#
# The ranked queue prioritizes pages that may benefit most from content review based on historical search signals.
#
# ### Priority Actions
#
# 1. Review pages with high impressions that have not been updated recently.
# 2. Improve pages with low click-through rates despite good visibility.
# 3. Review pages with declining search performance.
# 4. Update outdated content where appropriate.
#
# ### Reason Codes
#
# - RC1: High historical impressions
# - RC2: Long time since last update
# - RC3: Low click-through rate
# - RC4: Lower average search position
#
# These recommendations are intended to help content teams prioritize manual review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*
# ## Intended Use and Limits
#
# This playbook is designed for SEO and content teams to prioritize pages for manual review. The recommendations are based on observed historical search signals and should be treated as decision-support.
#
# The recommendations should not automatically trigger content changes because external factors such as seasonality, algorithm updates, or business priorities are not represented in the dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*
# ## Human Review
#
# Before updating any page, a reviewer should verify:
#
# - The content is still accurate.
# - Business priorities support updating the page.
# - Search intent has not changed.
# - No technical SEO issues exist.
#
# ### No-Go List
#
# The following actions should never be fully automated:
#
# - Publishing rewritten content.
# - Deleting content.
# - Changing business-critical information.
# - Making decisions without human approval.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*
# ## Monitoring and Retraining
#
# The model should be reviewed when:
#
# - Search performance changes significantly.
# - New content is added regularly.
# - Search engine ranking behavior changes.
# - Model performance decreases on newly collected data.
#
# Retraining should occur whenever sufficient new historical data becomes available.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*
# ## Export Files
#
# The ranked action queue is exported for inclusion in the final paper. These outputs provide supporting evidence for the recommendations generated by the baseline model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import sys
import subprocess
import pandas as pd

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git","clone","--depth","1",REPO_URL,REPO_DIR], check=True)
    os.chdir(REPO_DIR)

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["action_score"] = (
    df["impressions_90d"].fillna(0)
    + df["days_since_last_update"].fillna(0)
    - 10 * df["avg_position"].fillna(0)
)

queue = df.sort_values("action_score", ascending=False)

os.makedirs("work/outputs", exist_ok=True)

queue.to_csv(
    "work/outputs/content_action_queue.csv",
    index=False
)

print("Top 20 recommendations:")
print(
    queue[
        [
            "action_score",
            "impressions_90d",
            "days_since_last_update",
            "avg_position"
        ]
    ].head(20)
)

print("\nSaved to:")
print("work/outputs/content_action_queue.csv")
# Out:
# Top 20 recommendations:
#        action_score  impressions_90d  days_since_last_update  avg_position
# 6653       517777.0           517715                     104           4.2
# 17812      517077.0           517109                      22           5.4
# 26844      509247.0           509252                      20           2.5
# 19636      497553.0           497727                      48          22.2
# 21819      463100.0           463103                      20           2.3
# 29400      443259.0           443434                     104          27.9
# 29879      416162.0           416180                      22           4.0
# 13537      347461.0           347399                     104           4.2
# 18870      345077.0           345111                      20           5.4
# 14090      312700.0           312694                      20           1.4
# 26531      309958.0           309910                     104           5.6
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

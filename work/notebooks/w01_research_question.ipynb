# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RayyanA24/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# ## My Lane: Content Refresh Prioritization
#
# I chose the Content Refresh Prioritization lane because the goal is to identify which content pages should be reviewed and updated first based on their historical performance. This problem is useful because websites often contain many pages, making it difficult to decide where to spend time. By analyzing historical search performance, I hope to build a decision-support system that helps prioritize pages for review instead of relying on manual judgment alone.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# ## Research Question
#
# **Decision:** Which content pages should be prioritized for content refresh?
#
# **Action:** A content or SEO team can review and update the highest-priority pages first.
#
# **Cost of a wrong recommendation:** If a healthy page is prioritized unnecessarily, time and resources are wasted. If an important declining page is missed, valuable search traffic may continue to decrease.
#
# Machine learning can help by identifying patterns across multiple features that are difficult to evaluate consistently using manual rules alone.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# ## Quick Look at the Data
#
# The starter dataset provides useful evidence that this problem is worth studying. I will examine a few simple statistics from the dataset to understand relationships between search performance and page characteristics before building any predictive model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/flyrank-ml-internship-starter

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# %%
import os

print("Current directory:", os.getcwd())
print("data exists:", os.path.exists("data"))
print("raw exists:", os.path.exists("data/raw"))

print("\nFiles in data/raw:")
print(os.listdir("data/raw"))
# Out:
# Current directory: /content/flyrank-ml-internship-starter
# data exists: True
# raw exists: True
#
# Files in data/raw:
# ['content_refresh_anonymized.csv']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

filtered = df[df["impressions_90d"] > 0]

corr = filtered["search_volume"].corr(filtered["impressions_90d"])

print(f"Correlation after filtering impressions > 0: {corr:.3f}")

median_wc = df.groupby("trend_direction")["word_count"].median()

print("\nMedian word count by trend direction:")
print(median_wc)
# Out:
# Rows: 30000
# Columns: 44
# Correlation after filtering impressions > 0: 0.001
#
# Median word count by trend direction:
# trend_direction
# down      2909.0
# flat      2698.5
# new       2239.0
# stable    2912.5
# up        2847.5
# Name: word_count, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
